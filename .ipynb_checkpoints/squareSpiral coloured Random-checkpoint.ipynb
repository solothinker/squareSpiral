# %% [markdown]
# # Coloured Square Spiral

# %%
# %matplotlib nbagg
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
# R = 256
# G = 256
# B = 256
pix = 256
nAxis = int(np.sqrt(pix*pix*pix))
low = 0
high = nAxis-1
count = int((nAxis+1)/2)

# %% [markdown]
# <a href="https://www.youtube.com/watch?v=3hLlxWDQZcI">Reference Link</a>

# %%
# %%time
cList =[]
for ii in range(count):
    for jj in range(low,high+1,1): # top index
        cList.append((ii,jj))
    for jj in range(low+1,high+1,1): # last column
        cList.append((jj,high))
    for jj in range(high-1,low-1,-1):
        cList.append((high,jj))
    for jj in range(high-1,low,-1):
        cList.append((jj,low))
    low += 1
    high -= 1
# Out:
# CPU times: user 4.4 s, sys: 487 ms, total: 4.88 s
# Wall time: 4.89 s

# %%
R = np.zeros((nAxis,nAxis),dtype=np.uint8)
G = np.zeros((nAxis,nAxis),dtype=np.uint8)
B = np.zeros((nAxis,nAxis),dtype=np.uint8)

# %%
# %%time
indx = 0
for r in range(pix):
    for g in range(pix):
        for b in range(pix):
            R[cList[indx]] = r
            G[cList[indx]] = g
            B[cList[indx]] = b
            indx += 1
# Out:
# CPU times: user 13.3 s, sys: 11.2 ms, total: 13.3 s
# Wall time: 13.3 s

# %%
# %%time
img_bgr = cv2.merge([R,G,B])
plt.figure(figsize = (10,10))
plt.imshow(img_bgr)
plt.axis('off')
plt.savefig('RGB.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# CPU times: user 527 ms, sys: 56.1 ms, total: 583 ms
# Wall time: 579 ms

# %%
# %%time
img_bgr = cv2.merge([R,B,G])
plt.figure(figsize = (10,10))
plt.imshow(img_bgr)
plt.axis('off')
plt.savefig('RBG.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# CPU times: user 546 ms, sys: 39.8 ms, total: 585 ms
# Wall time: 580 ms

# %%
# %%time
img_bgr = cv2.merge([B,R,G])
plt.figure(figsize = (10,10))
plt.imshow(img_bgr)
plt.axis('off')
plt.savefig('BRG.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# CPU times: user 520 ms, sys: 60 ms, total: 580 ms
# Wall time: 576 ms

# %%
# %%time
img_bgr = cv2.merge([B,G,R])
plt.figure(figsize = (10,10))
plt.imshow(img_bgr)
plt.axis('off')
plt.savefig('BGR.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# CPU times: user 518 ms, sys: 60.3 ms, total: 578 ms
# Wall time: 573 ms

# %%
# %%time
img_bgr = cv2.merge([G,B,R])
plt.figure(figsize = (10,10))
plt.imshow(img_bgr)
plt.axis('off')
plt.savefig('GBR.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# CPU times: user 532 ms, sys: 44.4 ms, total: 576 ms
# Wall time: 571 ms

# %%
# %%time
img_bgr = cv2.merge([G,R,B])
plt.figure(figsize = (10,10))
plt.imshow(img_bgr)
plt.axis('off')
plt.savefig('GRB.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# CPU times: user 543 ms, sys: 40.2 ms, total: 583 ms
# Wall time: 578 ms
