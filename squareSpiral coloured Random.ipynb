# %% [markdown]
# # Random Coloured Square Spiral

# %%
# %matplotlib nbagg
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random

# %%
# R = 256
# G = 256
# B = 256
pix = 256
nAxis = int(np.sqrt(pix*pix*pix))
low = 0
high = nAxis-1
count = int((nAxis+1)/2)
random.seed(1)

# %% [markdown]
# <a href="https://www.youtube.com/watch?v=3hLlxWDQZcI">Reference Link</a>

# %%
# %%time
cList =[]
for ii in range(count):
    for jj in range(low,high+1,1): # top index
        cList.append((ii,jj))
    for jj in range(low+1,high+1,1): # last column
        cList.append((jj,high))
    for jj in range(high-1,low-1,-1):
        cList.append((high,jj))
    for jj in range(high-1,low,-1):
        cList.append((jj,low))
    low += 1
    high -= 1
# Out:
# CPU times: user 4.05 s, sys: 388 ms, total: 4.44 s
# Wall time: 4.44 s

# %%
R = np.zeros((nAxis,nAxis),dtype=np.uint8)
G = np.zeros((nAxis,nAxis),dtype=np.uint8)
B = np.zeros((nAxis,nAxis),dtype=np.uint8)

# %%
# %%time
indx = 0
for r in range(pix):
    for g in range(pix):
        for b in range(pix):
            R[cList[indx]] = random.randint(0,r)
            G[cList[indx]] = random.randint(0,g)
            B[cList[indx]] = random.randint(0,r)
            indx += 1
# Out:
# CPU times: user 2min 19s, sys: 27.9 ms, total: 2min 19s
# Wall time: 2min 19s

# %%
# %%time
img_bgr = cv2.merge([R,G,B])
plt.figure(figsize = (5,5))
plt.imshow(img_bgr)
plt.axis('off')
# plt.savefig('RGB.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">
# CPU times: user 278 ms, sys: 94.9 ms, total: 372 ms
# Wall time: 226 ms

# %%
# %%time
img_bgr = cv2.merge([R,B,G])
plt.figure(figsize = (5,5))
plt.imshow(img_bgr)
plt.axis('off')
# plt.savefig('RBG.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">
# CPU times: user 175 ms, sys: 47.9 ms, total: 223 ms
# Wall time: 219 ms

# %%
# %%time
img_bgr = cv2.merge([B,R,G])
plt.figure(figsize = (5,5))
plt.imshow(img_bgr)
plt.axis('off')
# plt.savefig('BRG.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">
# CPU times: user 219 ms, sys: 7.98 ms, total: 227 ms
# Wall time: 222 ms

# %%
# %%time
img_bgr = cv2.merge([B,G,R])
plt.figure(figsize = (5,5))
plt.imshow(img_bgr)
plt.axis('off')
# plt.savefig('BGR.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">
# CPU times: user 221 ms, sys: 25 µs, total: 221 ms
# Wall time: 216 ms

# %%
# %%time
img_bgr = cv2.merge([G,B,R])
plt.figure(figsize = (5,5))
plt.imshow(img_bgr)
plt.axis('off')
# plt.savefig('GBR.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">
# CPU times: user 203 ms, sys: 24 ms, total: 227 ms
# Wall time: 223 ms

# %%
# %%time
img_bgr = cv2.merge([G,R,B])
plt.figure(figsize = (5,5))
plt.imshow(img_bgr)
plt.axis('off')
# plt.savefig('GRB.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">
# CPU times: user 209 ms, sys: 20 ms, total: 229 ms
# Wall time: 223 ms
