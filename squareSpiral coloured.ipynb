# %% [markdown]
# # Coloured Square Spiral

# %%
# %matplotlib nbagg
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
# R = 256
# G = 256
# B = 256
pix = 256
nAxis = int(np.sqrt(pix*pix*pix))
low = 0
high = nAxis-1
count = int((nAxis+1)/2)

# %% [markdown]
# <a href="https://www.youtube.com/watch?v=3hLlxWDQZcI">Reference Link</a>

# %%
# %%time
cList =[]
for ii in range(count):
    for jj in range(low,high+1,1): # top index
        cList.append((ii,jj))
    for jj in range(low+1,high+1,1): # last column
        cList.append((jj,high))
    for jj in range(high-1,low-1,-1):
        cList.append((high,jj))
    for jj in range(high-1,low,-1):
        cList.append((jj,low))
    low += 1
    high -= 1
# Out:
# CPU times: user 4.67 s, sys: 464 ms, total: 5.14 s
# Wall time: 5.14 s

# %%
R = np.zeros((nAxis,nAxis),dtype=np.uint8)
G = np.zeros((nAxis,nAxis),dtype=np.uint8)
B = np.zeros((nAxis,nAxis),dtype=np.uint8)

# %%
# %%time
# indx = 0
# for r in range(pix):
#     for g in range(pix):
#         for b in range(pix):
#             R[cList[indx]] = r
#             G[cList[indx]] = g
#             B[cList[indx]] = b
#             indx += 1
# Out:
# CPU times: user 15.4 s, sys: 45.1 ms, total: 15.4 s
# Wall time: 15.4 s

# %%
# %%time

flagG=False
flagB=False 
indx = 0
for r in range(pix):
    flagG != flagG
    
    for g in range(pix):
        flagB != flagB
        
        for b in range(pix):
            R[cList[indx]] = r

            if flagG:
                G[cList[indx]] = g
            else:
                G[cList[indx]] = 255-g
            
            if flagB:
                B[cList[indx]] = b
            else:
                B[cList[indx]] = 255-b
            indx += 1
# Out:
# CPU times: user 17.2 s, sys: 0 ns, total: 17.2 s
# Wall time: 17.2 s

# %%
# %%time
img_bgr = cv2.merge([R,G,B])
plt.figure(figsize = (10,10))
plt.imshow(img_bgr)
plt.axis('off')
plt.savefig('RGB.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# CPU times: user 552 ms, sys: 328 ms, total: 880 ms
# Wall time: 3.99 s

# %%
# %%time
img_bgr = cv2.merge([R,B,G])
plt.figure(figsize = (10,10))
plt.imshow(img_bgr)
plt.axis('off')
plt.savefig('RBG.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# CPU times: user 560 ms, sys: 114 ms, total: 674 ms
# Wall time: 672 ms

# %%
# %%time
img_bgr = cv2.merge([B,R,G])
plt.figure(figsize = (10,10))
plt.imshow(img_bgr)
plt.axis('off')
plt.savefig('BRG.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# CPU times: user 550 ms, sys: 116 ms, total: 666 ms
# Wall time: 725 ms

# %%
# %%time
img_bgr = cv2.merge([B,G,R])
plt.figure(figsize = (10,10))
plt.imshow(img_bgr)
plt.axis('off')
plt.savefig('BGR.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# CPU times: user 834 ms, sys: 71.4 ms, total: 905 ms
# Wall time: 1.08 s

# %%
# %%time
img_bgr = cv2.merge([G,B,R])
plt.figure(figsize = (10,10))
plt.imshow(img_bgr)
plt.axis('off')
plt.savefig('GBR.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# CPU times: user 597 ms, sys: 32.3 ms, total: 629 ms
# Wall time: 624 ms

# %%
# %%time
img_bgr = cv2.merge([G,R,B])
plt.figure(figsize = (10,10))
plt.imshow(img_bgr)
plt.axis('off')
plt.savefig('GRB.jpg',dpi=80)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# CPU times: user 561 ms, sys: 36.3 ms, total: 598 ms
# Wall time: 594 ms
